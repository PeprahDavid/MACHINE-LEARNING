# %%
import numpy as np
from numpy import mean
from numpy import std
from numpy import absolute
import math
from numpy import arange

from pandas import read_csv
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
import seaborn as sns
import pylab

from scipy import stats
import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import KFold
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV

# %%
#THE CCT DATA
dataframe = pd.read_csv('CCT-TFS syyskuu Henry.csv')
dataframe
print(dataframe.shape)
#print(dataframe.head(n=4))
dataframe
dataframe.dropna(inplace=True)
# Out:
# (1272, 14)

# %%
#CENTERING THE DATA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

#centered_dat=boston_features_df.copy()
new_dat=dataframe.drop(['Steel'], axis=1)
centered_dat=pd.DataFrame(scaler.fit_transform(new_dat), columns=new_dat.columns)
centered_dat.head()
# Out:
#           C        Si        Mn        Cr        Mo        Ni        Al  \
# 0 -0.981735 -0.426369 -1.296763 -0.783937 -0.800529 -0.477096 -0.197778
# 1 -0.981735 -0.426369 -1.296763 -0.783937 -0.800529 -0.477096 -0.197778
# 2 -0.981735 -0.426369 -1.296763 -0.783937 -0.800529 -0.477096 -0.197778
# 3 -0.981735 -0.426369 -1.314646 -0.783937 -0.800529 -0.477096 -0.197778
# 4 -0.981735 -0.426369 -1.314646 -0.783937 -0.800529 -0.477096 -0.197778
#
#          Cu      ppmB        Pa        Rc      lnRc      Texp
# 0  0.563468 -0.376174  0.052783  5.117114  2.340625  0.906620
# 1  0.563468 -0.376174  0.052783  0.496718  1.521658  1.653774
# 2  0.563468 -0.376174  0.052783 -0.207556  0.444309  2.080719
# 3  0.563468 -0.376174  0.052783 -0.261385 -0.630567  2.400928
# 4  0.563468 -0.376174  0.052783 -0.265512 -1.689007  2.721137

# %%
#NORMALIZING THE DATA
#dat=dataframe.drop(['Steel'],axis=1)
scaler=MinMaxScaler()
new_dat[new_dat.columns.values] = scaler.fit_transform(new_dat)
new_dat

#STANDARDIZED DATA; CENTERED(WITHOUT MEAN) + NORMALIZED (KEPT WITHIN A RANGE)
# Out:
#              C        Si        Mn        Cr        Mo        Ni        Al  \
# 0     0.130952  0.102662  0.043738  0.014599  0.000000  0.011342  0.000000
# 1     0.130952  0.102662  0.043738  0.014599  0.000000  0.011342  0.000000
# 2     0.130952  0.102662  0.043738  0.014599  0.000000  0.011342  0.000000
# 3     0.130952  0.102662  0.041750  0.014599  0.000000  0.011342  0.000000
# 4     0.130952  0.102662  0.041750  0.014599  0.000000  0.011342  0.000000
# ...        ...       ...       ...       ...       ...       ...       ...
# 1267  0.214286  0.136882  0.159046  0.204380  0.007576  0.003781  0.023697
# 1268  0.214286  0.136882  0.159046  0.204380  0.007576  0.003781  0.023697
# 1269  0.214286  0.136882  0.159046  0.204380  0.007576  0.003781  0.023697
# 1270  0.214286  0.152091  0.353877  0.049270  0.007576  0.217391  0.023697
# 1271  0.214286  0.155894  0.361829  0.049270  0.469697  0.005671  0.023697
#
#             Cu      ppmB        Pa        Rc      lnRc      Texp
# ...

# %%
#DEPENDENT AND INDEPENDENT VARIABLES
#x=Dependent Variables
#y=Independent Variables

data = pd.DataFrame.values
x=new_dat.drop(['Texp'], axis = 1)
y=new_dat.Texp
x=x.astype(float)
y=y.astype(float)

# %%
data = pd.DataFrame.values

x=new_dat.drop(['Texp'], axis = 1)
y=new_dat[['Texp']]
x=x.astype(float)
y=y.astype(float)
#model = sm.OLS(y, sm.add_constant(x)).fit()

new_x=sm.add_constant(x)
trans_x=new_x.T

dataFrame1 = pd.DataFrame(data=trans_x)
dataFrame2 = pd.DataFrame(data=new_x)
dataFrame3 = pd.DataFrame(data=y)

result1 = dataFrame1.dot(dataFrame2)
result2 = dataFrame1.dot(dataFrame3)
result3 = np.linalg.inv(result1)
result4=result3.dot(result2)
result4

weights_b = result4
weights_b


dataFrame4=new_x.dot(weights_b)
xb=dataFrame4

dataFrame4 = pd.DataFrame(data=y)
dataFrame5 = pd.DataFrame(data=xb)

# %%
# FINDING THE RESIDUALS FROM THE ORDINARY LEAST SQUARES
model_Simple = sm.OLS(y, x).fit()

model = sm.OLS(y, sm.add_constant(x)).fit()

residuals=model.resid
#residuals

# %%
#CALCULATING THE BETA FOR WLS
data = pd.DataFrame.values

x=new_dat.drop(['Texp'], axis = 1)
y=new_dat[['Texp']]
x=x.astype(float)
y=y.astype(float)
#model = sm.OLS(y, sm.add_constant(x)).fit()

new_x=sm.add_constant(x)
trans_x=new_x.T


residuals = pd.DataFrame(data=residuals)
residuals

weight_wls = 1/residuals
weight_wls_diagonal_matrix = np.diag(weight_wls[0])

trans_x = pd.DataFrame(data=trans_x)
new_x = pd.DataFrame(data=new_x)
y = pd.DataFrame(data=y)
diag_wls = pd.DataFrame(data=weight_wls_diagonal_matrix)

x_trans_by_diag_wls = trans_x.dot(diag_wls)
x_trans_by_diag_wls_by_x = x_trans_by_diag_wls.dot(new_x)
x_trans_by_diag_wls_by_x_inv = np.linalg.inv(x_trans_by_diag_wls_by_x)
x_trans_by_diag_wls_by_x_inv = pd.DataFrame(data=x_trans_by_diag_wls_by_x_inv)

x_trans_by_diag_wls_by_y = x_trans_by_diag_wls.dot(y)
#beta_for_wls = x_trans_by_diag_wls_by_x_inv.dot(x_trans_by_diag_wls_by_y)
qq=x_trans_by_diag_wls_by_y
ww=x_trans_by_diag_wls_by_x_inv

Q1=x_trans_by_diag_wls_by_x_inv
Q2=x_trans_by_diag_wls.dot(y)

#MATHS IS CORRECT BUT PANDAS IS GIVING ERRORS
#CONVERTING PANDAS MATRIX TO NUMPY.
#Q1.dot(Q2)
ere=Q1.to_numpy()
#ere.shape
ET = Q2.to_numpy()
weights_for_wls=np.matmul(ere,ET)


weights_for_wls = pd.DataFrame(data=weights_for_wls)
#weights_for_wls
# Out:
#              0
# 0     0.102165
# 1     0.097571
# 2     0.085821
# 3     0.065821
# 4     0.049009
# ...        ...
# 1267  0.118995
# 1268  0.164958
# 1269  0.195785
# 1270 -0.065529
# 1271 -0.054702
#
# [1272 rows x 1 columns]

# %%
#FINDING THE TRUE Y FOR WLS
#Y=XB
ET1=new_x.to_numpy()
ET2=weights_for_wls.to_numpy()

true_y=np.matmul(ET1,ET2)
true_y = pd.DataFrame(data=true_y)
#true_y

# %%
#FINDING THE RESIDUALS FOR WLS
residuals_for_wls=ET3**2

residuals_for_wls = pd.DataFrame(data=residuals_for_wls)
residuals_for_wls
#new_x.dot(weights_for_wls)
# Out:
#              0
# 0     1.203668
# 1     1.445157
# 2     1.604883
# 3     1.764526
# 4     1.911329
# ...        ...
# 1267  0.799157
# 1268  0.832623
# 1269  0.863353
# 1270  0.181994
# 1271  0.128733
#
# [1272 rows x 1 columns]

# %%
mod_wls = sm.WLS(true_y, new_x, weights=1./(residuals_for_wls ** 2))
#mod_wls = sm.WLS(y, X, weights=1./(w ** 2))
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                             WLS Regression Results
# ...
# Dep. Variable:                      0   R-squared:                       1.000
# Model:                            WLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.169e+25
# Date:                Thu, 15 Apr 2021   Prob (F-statistic):               0.00
# Time:                        17:37:23   Log-Likelihood:                 30260.
# No. Observations:                1272   AIC:                        -6.049e+04
# Df Residuals:                    1259   BIC:                        -6.043e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.6170   2.64e-13   6.12e+12      0.000       1.617       1.617
# ...

# %%
data = pd.DataFrame.values

x=new_dat.drop(['Texp'], axis = 1)
y=new_dat[['Texp']]
x=x.astype(float)
y=y.astype(float)
model = sm.OLS(y, sm.add_constant(x)).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Texp   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     371.1
# Date:                Thu, 15 Apr 2021   Prob (F-statistic):               0.00
# Time:                        17:19:25   Log-Likelihood:                 1475.9
# No. Observations:                1272   AIC:                            -2926.
# Df Residuals:                    1259   BIC:                            -2859.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0547      0.012     91.489      0.000       1.032       1.077
# ...
